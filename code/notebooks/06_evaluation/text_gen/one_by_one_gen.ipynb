# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers datasets rouge-score --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for rouge-score (setup.py) ... done

# %%
from datasets import load_dataset

# CHANGE THIS PATH to your file
data_path = "/content/drive/MyDrive/biomedical_text_generation/data/unseen/title_text_gen_unseen.jsonl"

dataset_dict = load_dataset(
    "json",
    data_files={"test": data_path}
)

test_dataset = dataset_dict["test"]

print("Dataset loaded successfully")
print("Number of examples:", len(test_dataset))
print("\nExample record:")
print(test_dataset[0])
# Out:
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset loaded successfully
# Number of examples: 3777
#
# Example record:
# {'input': 'Study on the Effects and Mechanism of Corilagin on A2780 Cell Apoptosis.', 'target': "Previous studies have demonstrated corilagin's inhibitory effects on the growth of various cancer cells. Given the limited research on corilagin's impact on ovarian cancer, a particularly deadly gynecological malignancy, this study aimed to investigate corilagin's influence on A2780 ovarian cancer cell apoptosis and its underlying mechanisms. The goal was to evaluate corilagin's potential as a therapeutic agent for ovarian cancer. The results of the CCK8 assay showed that corilagin inhibited the proliferation of A2780 ovarian cancer cells while exhibiting lower toxicity to normal ovarian surface epithelial cells (IOSE80). We found that corilagin significantly altered the A2780 cell cycle, decreasing the proportion of cells in the Gsub0subGsub1sub and Gsub2subM phases and inducing cell cycle arrest in the S phase. At low concentrations, corilagin induced apoptosis in A2780 cells, accompanied by a decline in mitochondrial membrane potential and calcium influx. Transcriptome sequencing analysis identified differentially expressed apoptosisrelated genes in corilagintreated A2780 cells, primarily within the PI3KAKT pathway. Furthermore, qPCR and Western blot results confirmed the upregulation of ip53i and iBaxi genes and the downregulation of BCL2. Corilagin also increased the expression of apoptotic factors caspase9, caspase3, PUMA, and cytochrome C, indicating its ability to induce apoptosis. Overall, corilagin effectively inhibited A2780 cell proliferation, induced cell cycle arrest, and triggered apoptosis. Its antitumor effect in vitro suggests its potential as a therapeutic agent for ovarian cancer A2780, especially through the PI3Kp53 pathway."}

# %%
index = 3775

# %%
####################### BIOBART #################################################
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# 🔁 CHANGE MODEL HERE to compare models
# model_checkpoint = "GanjinZero/biobart-v2-base"
#model_checkpoint = "QizhiPei/biot5-base"
# model_checkpoint = "GanjinZero/biobart-base"
#model_checkpoint = "/content/drive/MyDrive/biomedical_text_generation/models/biot5_sum_final"
model_checkpoint = "/content/drive/MyDrive/biomedical_text_generation/models/biov2bart_title_text_gen_final"


tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

model = AutoModelForSeq2SeqLM.from_pretrained(
    model_checkpoint
).to("cuda")

model.eval()

print("Model loaded:", model_checkpoint)
# Out:
# Loading weights:   0%|          | 0/260 [00:00<?, ?it/s]
# Model loaded: /content/drive/MyDrive/biomedical_text_generation/models/biov2bart_title_text_gen_final

# %%
####################### BIOBART #################################################

def generate_summary(input_text,
                     max_input_length=128,
                     max_new_tokens=1024,
                     num_beams=4):

    inputs = tokenizer(
        input_text,
        return_tensors="pt",
        truncation=True,
        max_length=max_input_length
    ).to("cuda")

    with torch.no_grad():
        summary_ids = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            num_beams=num_beams,
            early_stopping=True
        )

    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# %%
####################### BIOBART #################################################

# 🔁 Change this number each time

input_text = test_dataset[index]["input"]

target_text = test_dataset[index]["target"]

generated_text = generate_summary(input_text)

print("\n" + "="*100)
print("MODEL:", model_checkpoint)
print("INDEX:", index)
print("="*100)

print("\nINPUT:\n")
print(input_text)

print("\nTARGET:\n")
print(target_text)

print("\nGENERATED (MODEL OUTPUT) BioBART:\n")
print(generated_text)

print("\n" + "="*100)
# Out:
# ====================================================================================================
# MODEL: /content/drive/MyDrive/biomedical_text_generation/models/biov2bart_title_text_gen_final
# INDEX: 3775
# ====================================================================================================
#
# INPUT:
#
# Frailty in robotic pancreaticoduodenectomy: quantifying the impact on perioperative outcomes.
#
# TARGET:
#
# We sought to determine the significance of age and frailty in predicting perioperative outcomes of robotic pancreaticoduodenectomy (RPD). Data from our institution's prospectively collected robotic pancreaticoduodenectomy database was analyzed for the years 20182023. The 5factor modified frailty index (mFI5) was used as a concise stratification tool for frailty. Predictive models for composite adverse event (CAE) variable were created using adjusted logistic regressions. 116 patients underwent RPD. Mean age of this cohort was 70.65 years (11.44). The mean operative time was 311.47 min (71.35) and the estimated blood loss was 107.07 mL (128.49). The most common postoperative complications included in the CAE were pancreatic leak (n  10, 8.62 ), delayed gastric emptying (n  10, 8.62 ), bleeding (n  5, 4.31 ), and atrial fibrillation (n  2, 1.72 ). The 90day mortality was 1.72 . There was a gradual increase in the odds ratio of CAE with increasing mFI5 score: OR 1.52 (95  CI 0.259.20) for mFI5 score of 1 and OR 31.92 (95  CI 1.79570.09) for mFI5 score of 4 compared to score of 0. Preoperative mFI5 score may serve as a risk stratification tool for RPDs.
#
# GENERATED (MODEL OUTPUT) BioBART:
#
# Robotic pancreaticoduodenectomy (DP) is increasingly used to treat pancreatic ductal adenocarcinoma (PDAC). Frailty, defined as the presence of multiple comorbidities, has been linked to worse outcomes in various cancers, including PDAC. This study aims to quantify the impact of frailty on perioperative outcomes in patients undergoing DP. A retrospective analysis was conducted on patients who underwent DP at the Royal Marsden NHS Foundation Trust between January 1, 2017, and December 31, 2022. Frailty was defined as having at least one of the following: (1) a frailty score of 01, (2) an age of 65 or older, (3) a BMI of 30, and (4) an educational level or higher. The primary outcome was 30day mortality. Secondary outcomes included 30day morbidity, 30day readmission, 90day mortality, and 90day readmission rates. Multivariable analysis identified frailty as an independent risk factor for 30day allcause mortality (hazard ratio [HR]  1.32, 95 confidence interval [CI] 1.031.67, p  0.001), 30day major complications (HR  2.02, 95 CI 1.022.44, p 0.002), 90day readmissions (HR 1.28, 95CI 1.051.57, p0.001) and 90 days mortality (HR 2.03, 95CIs 1.041.46, p1.001). The frailty group had a higher incidence of 30day postoperative complications, 90 days readmission, and 180day mortality compared with the nonfrail group, with these differences being more pronounced in the frail group. The study demonstrates that frailty is a significant predictor of adverse perioperative outcomes following DP, highlighting the need for individualized interventions tailored to individual frailty profiles.
#
# ====================================================================================================

# %%
################################## BIOT5 #######################################
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# 🔁 CHANGE MODEL HERE to compare models
# model_checkpoint = "GanjinZero/biobart-v2-base"
tok = "QizhiPei/biot5-base"
# model_checkpoint = "GanjinZero/biobart-base"
model_checkpoint = "/content/drive/MyDrive/biomedical_text_generation/models/biot5_title_text_gen_final"
#model_checkpoint = "/content/drive/MyDrive/biomedical_text_generation/models/biov2bart_sum_final"


tokenizer = AutoTokenizer.from_pretrained(tok)

model = AutoModelForSeq2SeqLM.from_pretrained(
    model_checkpoint
).to("cuda")

model.eval()

print("Model loaded:", model_checkpoint)
# Out:
# Loading weights:   0%|          | 0/282 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Model loaded: /content/drive/MyDrive/biomedical_text_generation/models/biot5_title_text_gen_final

# %%
################################## BIOT5 #######################################

def generate_summary(input_text,
                     max_input_length=128,
                     max_new_tokens=512,
                     num_beams=4):

    inputs = tokenizer(
        input_text,
        return_tensors="pt",
        truncation=True,
        max_length=max_input_length
    ).to("cuda")

    with torch.no_grad():
        summary_ids = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            num_beams=num_beams,
            early_stopping=True
        )

    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# %%
################################## BIOT5 #######################################

# 🔁 Change this number each time

input_text = "generate abstract: " + test_dataset[index]["input"]

target_text = test_dataset[index]["target"]

generated_text = generate_summary(input_text)

print("\n" + "="*100)
print("MODEL:", model_checkpoint)
print("INDEX:", index)
print("="*100)

print("\nINPUT:\n")
print(input_text)

print("\nTARGET (REFERENCE):\n")
print(target_text)

print("\nGENERATED (MODEL OUTPUT) BioT5:\n")
print(generated_text)

print("\n" + "="*100)
# Out:
# ====================================================================================================
# MODEL: /content/drive/MyDrive/biomedical_text_generation/models/biot5_title_text_gen_final
# INDEX: 3775
# ====================================================================================================
#
# INPUT:
#
# generate abstract: Frailty in robotic pancreaticoduodenectomy: quantifying the impact on perioperative outcomes.
#
# TARGET (REFERENCE):
#
# We sought to determine the significance of age and frailty in predicting perioperative outcomes of robotic pancreaticoduodenectomy (RPD). Data from our institution's prospectively collected robotic pancreaticoduodenectomy database was analyzed for the years 20182023. The 5factor modified frailty index (mFI5) was used as a concise stratification tool for frailty. Predictive models for composite adverse event (CAE) variable were created using adjusted logistic regressions. 116 patients underwent RPD. Mean age of this cohort was 70.65 years (11.44). The mean operative time was 311.47 min (71.35) and the estimated blood loss was 107.07 mL (128.49). The most common postoperative complications included in the CAE were pancreatic leak (n  10, 8.62 ), delayed gastric emptying (n  10, 8.62 ), bleeding (n  5, 4.31 ), and atrial fibrillation (n  2, 1.72 ). The 90day mortality was 1.72 . There was a gradual increase in the odds ratio of CAE with increasing mFI5 score: OR 1.52 (95  CI 0.259.20) for mFI5 score of 1 and OR 31.92 (95  CI 1.79570.09) for mFI5 score of 4 compared to score of 0. Preoperative mFI5 score may serve as a risk stratification tool for RPDs.
#
# GENERATED (MODEL OUTPUT) BioT5:
#
# Surveilli stenosarcoma is a challenging surgical modality. This study aimed to quantify frailty in robotic ...
#
# ====================================================================================================

# %%
import json

output_path = "/content/drive/MyDrive/biomedical_text_generation/test_predictions.json"

results = []

for i in range(len(test_dataset)):

    input_text = test_dataset[i]["input"]
    target_text = test_dataset[i]["target"]

    generated_text = generate_summary(input_text)

    results.append({
        "input": input_text,
        "target": target_text,
        "generated": generated_text
    })

with open(output_path, "w") as f:
    json.dump(results, f, indent=2)

print("Results saved to:", output_path)
